# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
api_key
# Out:
# 'e67d06ffbf1c6d98526ad6ec39522cfd'

# %%
# definition of weather check


url = "http://api.openweathermap.org/data/2.5/weather?"


# Build query URL

for i in range(len(cities)):
    
    query_url = url + "appid=" + api_key + "&q=" + cities[i]
    
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    #pprint(f"The weather API responded with: {weather_json}.")
    
    if weather_json['cod'] == '404':
        continue
    else:    
        pprint(weather_json['name'])
        pprint(weather_json['main']['temp'])
        print('\n')
# Get the temperature from the response
# Out:
# 'Bethel'
# 275.37
#
#
# 'Rikitea'
# 300.119
#
#
# 'Inta'
# 264.069
#
#
# 'Asosa'
# 288.344
#
#
# 'Kovdor'
# 262.469
#
#
# 'Nikolskoye'
# 269.15
#
#
# 'Pajapan'
# 295.15
#
#
# 'Kolondieba'
# 297.594
#
#
# 'Hermanus'
# 290.169
#
#
# 'Bambous Virieux'
# 300.15
#
#
# 'Yellowknife'
# 247.15
#
#
# 'Dryden'
# 264.15
#
#
# 'Medea'
# 282.15
#
#
# 'Awjilah'
# 286.944
#
#
# 'Ushuaia'
# 282.15
#
#
# 'Tasiilaq'
# 260.15
#
#
# 'Constitucion'
# 289.119
#
#
# 'Tuktoyaktuk'
# 244.15
#
#
# 'Provideniya'
# 272.15
#
#
# 'Punta Arenas'
# 286.62
#
#
# 'Arraial do Cabo'
# 304.43
#
#
# 'Hobart'
# 290.15
#
#
# 'Hamilton'
# 291.15
#
#
# 'Mayo'
# 258.15
#
#
# 'Coahuayana'
# 300.519
#
#
# 'Chaman'
# 272.119
#
#
# 'Cape Town'
# 294.15
#
#
# 'Qasigiannguit'
# 252.15
#
#
# 'Marawi'
# 287.669
#
#
# 'Straumen'
# 263.68
#
#
# 'Norman Wells'
# 250.15
#
#
# 'Torres'
# 299.819
#
#
# 'Vredendal'
# 287.719
#
#
# 'Mataura'
# 290.419
#
#
# 'Pueblo Nuevo'
# 300.744
#
#
# 'Torbay'
# 275.15
#
#
# 'Marevo'
# 267.15
#
#
# 'Avarua'
# 302.15
#
#
# 'Busselton'
# 288.594
#
#
# 'Albany'
# 271
#
#
# 'Muroto'
# 277.769
#
#
# 'Klaksvik'
# 276.15
#
#
# 'Kodiak'
# 273.75
#
#
# 'Dingle'
# 296.444
#
#
# 'Salekhard'
# 252.419
#
#
# 'Pauini'
# 299.694
#
#
# 'Ihosy'
# 294.319
#
#
# 'Berlevag'
# 265.84
#
#
# 'Verkhnyaya Inta'
# 261.994
#
#
# 'Nazas'
# 290.369
#
#
# 'Bandarbeyla'
# 297.344
#
#
# 'Mokrous'
# 272.944
#
#
# 'Finnsnes'
# 266.08
#
#
# 'Georgetown'
# 302.22
#
#
# 'Barrow'
# 303.844
#
#
# 'Keetmanshoop'
# 305.15
#
#
# 'Hulan'
# 273.48
#
#
# 'Nueva Imperial'
# 294.15
#
#
# 'Araripina'
# 300.219
#
#
# 'Boa Vista'
# 307.15
#
#
# 'Mar del Plata'
# 297.269
#
#
# 'Longyearbyen'
# 256.15
#
#
# 'Jamestown'
# 299.844
#
#
# 'Sangar'
# 232.519
#
#
# 'Sorland'
# 268.15
#
#
# 'Port Augusta'
# 296.15
#
#
# 'Kaitangata'
# 289.819
#
#
# 'Deputatskiy'
# 228.219
#
#
# 'Hithadhoo'
# 299.994
#
#
# 'Wuchang'
# 256.194
#
#
# 'Las Choapas'
# 295.15
#
#
# 'Kirakira'
# 302.094
#
#
# 'Hilo'
# 296.45
#
#
# 'Quang Ngai'
# 292.944
#
#
# 'Gidam'
# 282.844
#
#
# 'Lompoc'
# 285.49
#
#
# 'Saskylakh'
# 234.094
#
#
# 'Bogorodskoye'
# 250.744
#
#
# 'Vaini'
# 289.719
#
#
# 'Rorvik'
# 266.83
#
#
# 'Puerto Leguizamo'
# 298.419
#
#
# 'Puerto Ayora'
# 302.15
#
#
# 'Sinnamary'
# 299.219
#
#
# 'Souillac'
# 276.71
#
#
# 'Bol'
# 290.419
#
#
# 'Atuona'
# 300.069
#
#
# 'Isangel'
# 298.969
#
#
# 'Necochea'
# 301.119
#
#
# 'Port Elizabeth'
# 275.67
#
#
# 'Ponta do Sol'
# 303.344
#
#
# 'New Norfolk'
# 290.15
#
#
# 'Rocha'
# 294.069
#
#
# 'Karatau'
# 274.569
#
#
# 'Antalaha'
# 298.519
#
#
# 'Cap Malheureux'
# 300.15
#
#
# 'Yulara'
# 303.15
#
#
# 'Oktyabrskoye'
# 266.15
#
#
# 'Camocim'
# 297.419
#
#
# 'East London'
# 296.669
#
#
# 'Bluff'
# 295.669
#
#
# 'Rosario'
# 296.15
#
#
# 'Dikson'
# 259.844
#
#
# 'Vila Velha'
# 301.15
#
#
# 'Ilulissat'
# 252.15
#
#
# 'Price'
# 272.55
#
#
# 'Nantucket'
# 273.58
#
#
# 'Phuket'
# 296.59
#
#
# 'Port Blair'
# 300.744
#
#
# 'Atambua'
# 298.419
#
#
# 'Airai'
# 293.569
#
#
# 'Paragominas'
# 301.269
#
#
# 'Butaritari'
# 301.944
#
#
# 'Ahipara'
# 294.119
#
#
# 'Richards Bay'
# 296.569
#
#
# 'Bethalto'
# 273.34
#
#
# 'Cherskiy'
# 238.494
#
#
# 'Saint-Georges'
# 263.919
#
#
# 'Esperance'
# 303.15
#
#
# 'Lebu'
# 288.15
#
#
# 'Westport'
# 280.15
#
#
# 'Saint Anthony'
# 265.99
#
#
# 'San Patricio'
# 304.369
#
#
# 'Oranjemund'
# 291.069
#
#
# 'Severo-Kurilsk'
# 266.744
#
#
# 'Victoria'
# 298.15
#
#
# 'Leningradskiy'
# 253.719
#
#
# 'Port Alfred'
# 294.169
#
#
# 'Mahebourg'
# 300.15
#
#
# 'Tandil'
# 293.769
#
#
# 'Nome'
# 283.32
#
#
# 'Camacha'
# 289.15
#
#
# 'Minot'
# 266.64
#
#
# 'Qaanaaq'
# 237.494
#
#
# 'Cockburn Town'
# 299.169
#
#
# 'Tessaoua'
# 288.169
#
#
# 'Katsuura'
# 279.15
#
#
# 'Castro'
# 287.15
#
#
# 'Narsaq'
# 271.15
#
#
# 'Pevek'
# 249.694
#
#
# 'Komsomolskiy'
# 261.469
#
#
# 'Haines Junction'
# 255.669
#
#
# 'Khatanga'
# 246.219
#
#
# 'Wattegama'
# 293.494
#
#
# 'Okhotsk'
# 250.194
#
#
# 'Calarasi'
# 267.444
#
#
# 'Northam'
# 282.15
#
#
# 'Cabo San Lucas'
# 297.69
#
#
# 'Luanda'
# 299.15
#
#
# 'Chuy'
# 294.719
#
#
# 'Nynashamn'
# 268.63
#
#
# 'Coihaique'
# 288.5
#
#
# 'Egvekinot'
# 251.419
#
#
# 'Lorengau'
# 301.219
#
#
# 'Tambun'
# 298.15
#
#
# 'Vardo'
# 275.31
#
#
# 'Bredasdorp'
# 294.15
#
#
# 'Vostok'
# 248.569
#
#
# 'Sitka'
# 284.869
#
#
# 'Teya'
# 301.15
#
#
# 'Kahului'
# 297.35
#
#
# 'Tuatapere'
# 290.219
#
#
# 'Curup'
# 294.169
#
#
# 'Kuytun'
# 252.319
#
#
# 'Portland'
# 278.15
#
#
# 'Kurmanayevka'
# 268.469
#
#
# 'Oum Hadjer'
# 293.069
#
#
# 'Pisco'
# 295.15
#
#
# 'Balabac'
# 300.619
#
#
# 'Troitsko-Pechorsk'
# 266.619
#
#
# 'San Francisco del Mar'
# 299.969
#
#
# 'Thompson'
# 247.15
#
#
# 'Tiksi'
# 230.619
#
#
# 'Luderitz'
# 293.369
#
#
# 'Nanortalik'
# 271.594
#
#
# 'Bow Island'
# 270.15
#
#
# 'Spencer'
# 272.14
#
#
# 'Smithers'
# 272.15
#
#
# 'Tigil'
# 244.819
#
#
# 'Port Lincoln'
# 292.869
#
#
# 'Rumoi'
# 270.569
#
#
# 'Kloulklubed'
# 301.169
#
#
# 'Marfino'
# 267.64
#
#
# 'Angoche'
# 301.594
#
#
# 'Touros'
# 302.15
#
#
# 'San Andres'
# 298.994
#
#
# 'Kuryk'
# 279.844
#
#
# 'Carnarvon'
# 291.119
#
#
# 'Kalabo'
# 289.419
#
#
# 'Germantown'
# 271.16
#
#
# 'Mae Hong Son'
# 285.519
#
#
# 'Namatanai'
# 301.744
#
#
# 'Codrington'
# 294.17
#
#
# 'Plaster Rock'
# 265.76
#
#
# 'Murray Bridge'
# 292.569
#
#
# 'Lata'
# 273.569
#
#
# 'Kavieng'
# 301.944
#
#
# 'Handan'
# 263.769
#
#
# 'Bodden Town'
# 300.15
#
#
# 'Geraldton'
# 270.15
#
#
# 'Acari'
# 301.569
#
#
# 'Misratah'
# 287.719
#
#
# 'Atar'
# 289.569
#
#
# 'Vangaindrano'
# 296.994
#
#
# 'Roald'
# 268.36
#
#
# 'Saint-Philippe'
# 268.66
#
#
# 'Lavrentiya'
# 274.094
#
#
# 'Samarai'
# 301.344
#
#
# 'Pacifica'
# 284.75
#
#
# 'Hasaki'
# 274.03
#
#
# 'Chicama'
# 297.15
#
#
# 'Shache'
# 266.344
#
#
# 'Kavaratti'
# 301.069
#
#
# 'Cayenne'
# 301.15
#
#
# 'Kapaa'
# 299.07
#
#
# 'Biak'
# 298.844
#
#
# 'Havre-Saint-Pierre'
# 263.15
#
#
# 'Ribeira Grande'
# 289.15
#
#
# 'Morondava'
# 302.169
#
#
# 'Grand Gaube'
# 300.15
#
#
# 'Dawlatabad'
# 281.494
#
#
# 'Carolina'
# 300.47
#
#
# 'Senges'
# 297.219
#
#
# 'Russell'
# 303.15
#
#
# 'Turukhansk'
# 263.069
#
#
# 'Kumluca'
# 271.944
#
#
# 'Salalah'
# 296.15
#
#
# 'Daru'
# 300.169
#
#
# 'Tocopilla'
# 293.269
#
#
# 'Golden'
# 266.15
#
#
# 'Altamira'
# 301.15
#
#
# 'Araceli'
# 299.819
#
#
# 'Novyy Urengoy'
# 257.419
#
#
# 'Fairbanks'
# 247.29
#
#
# 'San Vicente'
# 306.15
#
#
# 'Dharchula'
# 271.194
#
#
# 'Hoopstad'
# 296.569
#
#
# 'Pastavy'
# 268.694
#
#
# 'Saint George'
# 274.62
#
#
# 'Atherton'
# 281.48
#
#
# 'Upington'
# 303.15
#
#
# 'Outram'
# 288.419
#
#
# 'Brae'
# 276.71
#
#
# 'Sosenskiy'
# 268.15
#
#
# 'Mayor Pablo Lagerenza'
# 309.119
#
#
# 'Wanning'
# 277.15
#
#
# 'Najran'
# 293.15
#
#
# 'Lagoa'
# 285.15
#
#
# 'Marquard'
# 288.419
#
#
# 'Amparafaravola'
# 294.069
#
#
# 'Liwale'
# 294.494
#
#
# 'Faanui'
# 302.244
#
#
# 'Ewo'
# 295.569
#
#
# 'Matara'
# 286.15
#
#
# 'Kapit'
# 296.669
#
#
# 'El Alto'
# 284.15
#
#
# 'Novopskov'
# 271.194
#
#
# 'Evensk'
# 245.619
#
#
# 'Sioux Lookout'
# 264.61
#
#
# 'Laguna'
# 297.15
#
#
# 'Gat'
# 301.13
#
#
# 'Antofagasta'
# 294.15
#
#
# 'Opuwo'
# 295.319
#
#
# 'Staraya Russa'
# 268.469
#
#
# 'Milkovo'
# 273.15
#
#
# 'Sawtell'
# 294.83
#
#
# 'Balkhash'
# 269.119
#
#
# 'Strezhevoy'
# 254.15
#
#
# 'Kruisfontein'
# 291.369
#
#
# 'Bulawayo'
# 292.594
#
#
# 'Shelburne'
# 272.15
#
#
# 'Kodinsk'
# 251.594
#
#
# 'Upernavik'
# 251.019
#
#
# 'Gusino'
# 266.094
#
#
# 'Kiruna'
# 263.15
#
#
# 'Naze'
# 301.15
#
#
# 'Hofn'
# 272.419
#
#
# 'Ostrovnoy'
# 258.694
#
#
# 'Ancud'
# 287.15
#
#
# 'Hovd'
# 265.23
#
#
# 'Tacoronte'
# 287.48
#
#
# 'San Cristobal'
# 290.62
#
#
# 'Banganapalle'
# 289.419
#
#
# 'Ilijas'
# 269.42
#
#
# 'Amahai'
# 300.619
#
#
# 'Svetlogorsk'
# 260.15
#
#
# 'Marsa Matruh'
# 287.15
#
#
# 'Bilibino'
# 234.444
#
#
# 'Faya'
# 287.64
#
#
# 'Dickinson'
# 270.35
#
#
# 'Samaniego'
# 289.05
#
#
# 'Todos Santos'
# 297.65
#
#
# 'Naryan-Mar'
# 261.819
#
#
# 'Sobolevo'
# 267.694
#
#
# 'Margate'
# 290.15
#
#
# 'Caravelas'
# 300.169
#
#
# 'Karera'
# 279.669
#
#
# 'Batagay'
# 216.469
#
#
# 'Nishihara'
# 275.72
#
#
# 'Huarmey'
# 298.519
#
#
# 'Chokurdakh'
# 232.269
#
#
# 'Saldanha'
# 270.844
#
#
# 'Tigzirt'
# 272.994
#
#
# 'Touba'
# 305.15
#
#
# 'Loa Janan'
# 297.019
#
#
# 'Filadelfia'
# 307.694
#
#
# 'Sibu'
# 297.15
#
#
# 'Clearlake'
# 284.35
#
#
# 'Lyudinovo'
# 268.619
#
#
# 'Ambilobe'
# 295.069
#
#
# 'Semnan'
# 277.15
#
#
# 'Burnie'
# 290.844
#
#
# 'Karachi'
# 292.444
#
#
# 'Chenzhou'
# 276.369
#
#
# 'Nizamabad'
# 287.469
#
#
# 'Cabedelo'
# 301.15
#
#
# 'Acapulco'
# 303.15
#
#
# 'Zelenchukskaya'
# 277.994
#
#
# 'Port Hardy'
# 278.15
#
#
# 'Tilichiki'
# 239.169
#
#
# 'Sitrah'
# 294.61
#
#
# 'Aklavik'
# 245.15
#
#
# 'Noumea'
# 297.15
#
#
# 'Isla Mujeres'
# 298.15
#
#
# 'Sherlovaya Gora'
# 251.619
#
#
# 'Ganta'
# 300.444
#
#
# 'Guane'
# 298.444
#
#
# 'Prieska'
# 293.494
#
#
# 'Maragogi'
# 299.494
#
#
# 'Honningsvag'
# 268.52
#
#
# 'Bouna'
# 296.844
#
#
# 'Taksimo'
# 250.994
#
#
# 'Solnechnyy'
# 247.994
#
#
# 'Makakilo City'
# 296.69
#
#
# 'Dunedin'
# 288.419
#
#
# 'Vanimo'
# 301.694
#
#
# 'Sakaiminato'
# 278.15
#
#
# 'Teo'
# 280.81
#
#
# 'Kilindoni'
# 301.594
#
#
# 'Taltal'
# 294.719
#
#
# 'Seminole'
# 284.6
#
#
# 'Bud'
# 269.21
#
#
# 'Pacific Grove'
# 285.69
#
#
# 'Dalbandin'
# 281.419
#
#
# 'Siguiri'
# 297.919
#
#
# 'Liku'
# 298.069
#
#
# 'Maniitsoq'
# 268.494
#
#
# 'Umm Lajj'
# 286.244
#
#
# 'Abrau-Dyurso'
# 281.15
#
#
# 'Tanout'
# 286.019
#
#
# 'Assiniboia'
# 264.869
#
#
# 'Okitipupa'
# 299.494
#
#
# 'Tabou'
# 301.719
#
#
# 'Zaqatala'
# 279.15
#
#
# 'Cianjur'
# 293.594
#
#
# 'Tiarei'
# 304.15
#
#
# 'Songjianghe'
# 248.819
#
#
# 'Sur'
# 293.619
#
#
# 'Pringsewu'
# 296.119
#
#
# 'Karpinsk'
# 262.769
#
#
# 'Prachuap Khiri Khan'
# 294.844
#
#
# 'Iqaluit'
# 253.15
#
#
# 'Kandrian'
# 297.744
#
#
# 'Gigmoto'
# 298.169
#
#
# 'Maningrida'
# 298.669
#
#
# 'Bonavista'
# 272.244
#
#
# 'Guerrero Negro'
# 292.444
#
#
# 'Natchitoches'
# 283.21
#
#
# 'Palana'
# 245.419
#
#
# 'Olga'
# 288.41
#
#
# 'Alice Springs'
# 302.15
#
#
# 'Flinders'
# 295.15
#
#
# 'Khani'
# 287.15
#
#
# 'Iquique'
# 297.15
#
#
# 'Axim'
# 301.669
#
#
# 'Dukat'
# 268.244
#
#
# 'Eskisehir'
# 271.65
#
#
# 'Iglesias'
# 274.15
#
#
# 'Chara'
# 274.63
#
#
# 'Islamabad'
# 281.15
#
#
# 'Fortuna'
# 284.14
#
#
# 'Ponta Delgada'
# 289.15
#
#
# 'Decatur'
# 275.44
#
#
# 'Bella Union'
# 300.069
#
#
# 'Bilma'
# 280.669
#
#
# 'Inuvik'
# 245.15
#
#
# 'Namie'
# 277.269
#
#
# 'Kholm'
# 267.769
#
#
# 'Juigalpa'
# 303.15
#
#
# 'Zhezkazgan'
# 262.994
#
#
# 'Mujiayingzi'
# 258.869
#
#
# 'Bang Saphan'
# 297.119
#
#
# 'Marzuq'
# 277.969
#
#
# 'Sexsmith'
# 262.15
#
#
# 'Santa Maria'
# 307.15
#
#
# 'Basoko'
# 295.344
#
#
# 'Lamas'
# 290.15
#
#
# 'Ubauro'
# 283.744
#
#
# 'Ugljevik'
# 271.15
#
#
# 'Tashara'
# 263.569
#
#
# 'Crixas'
# 302.969
#
#
# 'Rabat'
# 281.26
#
#
# 'Broken Hill'
# 303.15
#
#
# 'Parabel'
# 263.969
#
#
# 'Vila Franca do Campo'
# 289.15
#
#
# 'Yenagoa'
# 299.094
#
#
# 'Mikuni'
# 279.15
#
#
# 'Mount Gambier'
# 289.15
#
#
# 'Araouane'
# 287.569
#
#
# 'Ericeira'
# 283.92
#
#
# 'Williams Lake'
# 263.15
#
#
# 'Porto Nacional'
# 298.15
#
#
# 'Vestmanna'
# 276.15
#
#
# 'Barranca'
# 295.694
#
#
# 'Bichena'
# 280.744
#
#
# 'Lyubech'
# 271.094
#
#
# 'Darhan'
# 250.194
#
#
# 'Abu Dhabi'
# 294.15
#
#
# 'Benito Juarez'
# 296.094
#
#
# 'Batemans Bay'
# 296.344
#
#
# 'Langham'
# 255.15
#
#
# 'Bayir'
# 277.15
#
#
# 'Diu'
# 285.744
#
#
# 'Manitouwadge'
# 271.15
#
#
# 'Sandnessjoen'
# 267.56
#
#
# 'Blythe'
# 285.95
#
#
# 'Port Hedland'
# 302.15
#
#
# 'Half Moon Bay'
# 284.99
#
#
# 'Bridgetown'
# 270.15
#
#
# 'Grindavik'
# 272.15
#
#
# 'Kaniama'
# 292.344
#
#
# 'Valdivia'
# 290.15
#
#
# 'Labuhan'
# 294.244
#
#
# 'Careiro da Varzea'
# 303.66
#
#
# 'Independence'
# 274.15
#
#
# 'Gizo'
# 285.3
#
#
# 'Kitimat'
# 276.15
#
#
# 'La Ronge'
# 250.15
#
#
# 'Fengcheng'
# 252.069
#
#
# 'Sao Filipe'
# 295.694
#
#
# 'Loukhi'
# 266.694
#
#
# 'Nogliki'
# 260.469
#
#
# 'Trelew'
# 304.494
#
#
# 'San Policarpo'
# 298.069
#
#
# 'Beloha'
# 299.319
#
#
# 'Henties Bay'
# 291.194
#
#
# 'Los Llanos de Aridane'
# 291.15
#
#
# 'Eyl'
# 296.319
#
#
# 'Pontes e Lacerda'
# 303.844
#
#
# 'Mopti'
# 296.119
#
#
# 'Yatou'
# 300.15
#
#
# 'Itarema'
# 298.769
#
#
# 'Qaqortoq'
# 271.15
#
#
# 'Porto Walter'
# 300.194
#
#
# 'Yaan'
# 296.519
#
#
# 'Matagami'
# 293.669
#
#
# 'Libreville'
# 302.15
#
#
# 'Klyuchi'
# 261.769
#
#
# 'Pedernales'
# 299.344
#
#
# 'Sao Joao da Barra'
# 303.15
#
#
# 'Jalu'
# 286.019
#
#
# 'Nuuk'
# 267.15
#
#
# 'Bayji'
# 280.119
#
#
# 'Polyarnyy'
# 249.15
#
#
# 'Gulfport'
# 281.63
#
#
# 'Houma'
# 258.994
#
#
# 'Itoman'
# 291
#
#
# 'Tevriz'
# 260.744
#
#
# 'Nevelsk'
# 269.15
#
#
# 'Sambava'
# 299.694
#
#
# 'Eching'
# 276.91
#
#
# 'Greenfield'
# 272.54
#
#
# 'Aktau'
# 275.15
#
#
# 'Bayan'
# 249.244
#
#
# 'Praya'
# 297.15
#
#
# 'Datong'
# 248.069
#
#
# 'Yar-Sale'
# 257.669
#
#
# 'Alytus'
# 272.15
#
#
# 'Vao'
# 269.244
#
#
# 'Havoysund'
# 269.47
#
#
# 'Rudnichnyy'
# 262.769
#
#
# 'Luganville'
# 300.694
#
#
# 'Barcelos'
# 281.05
#
#
# 'Lasa'
# 286.58
#
#
# 'Puqi'
# 273.469
#
#
# 'Upata'
# 303.494
#
#
# 'Ontario'
# 287.79
#
#
# 'Petrozavodsk'
# 270.15
#
#
# 'Gawler'
# 296.15
#
#
# 'Ust-Tsilma'
# 265.319
#
#
# 'Ambanja'
# 295.194
#
#
# 'Muscle Shoals'
# 276.56
#
#
# 'Broome'
# 281.03
#
#
# 'Trincomalee'
# 297.094
#
#
# 'Coquimbo'
# 293.15
#
#
# 'Vung Tau'
# 297.269
#
#
# 'Arlit'
# 285.194
#
#
# 'Trofors'
# 267.6
#
#
# 'Port-Gentil'
# 301.15
#
#
# 'Bagdarin'
# 254.194
#
#
# 'Korsakov'
# 269.15
#
#
# 'Camopi'
# 298.219
#
#
# 'Kingman'
# 282.78
#
#
# 'Druzhba'
# 269.244
#
#
# 'Virginia Beach'
# 278.7
#
#
# 'Adrar'
# 285.15
#
#
# 'Wilmington'
# 274.96
#
#
# 'Collie'
# 286.194
#
#
# 'Praia da Vitoria'
# 288.15
#
#
# 'Kirensk'
# 255.019
#
#
# 'Kassala'
# 292.744
#
#
# 'Swan Hill'
# 297.269
#
#
# 'Weihe'
# 262.069
#
#
# 'Paysandu'
# 296.094
#
#
# 'Iquitos'
# 297.15
#
#
# 'Kita'
# 275.77
#
#
# 'Ternova'
# 268.12
#
#
# 'San Quintin'
# 290.344
#
#
# 'Hambantota'
# 298.569
#
#
# 'Santa Rosa'
# 302.419
#
#
# 'Oussouye'
# 298.86
#
#
# 'Kilgore'
# 281.86
#
#
# 'Muzhi'
# 254.669
#
#
# 'Tottori'
# 275.519
#
#
# 'Charters Towers'
# 294.094
#
#
# 'Kokopo'
# 300.319
#
#
# 'Belaya Gora'
# 235.944
#
#
# 'Akonolinga'
# 296.744
#
#
# 'Khash'
# 274.744
#
#
# 'Hobyo'
# 297.319
#
#
# 'Santa Cruz'
# 285.38
#
#
# 'Port-Cartier'
# 262.15
#
#
# 'Verkhoyansk'
# 218.569
#
#
# 'Kupang'
# 299.419
#
#
# 'Manaure'
# 305.15
#
#
# 'Vanavara'
# 255.669
#
#
# 'Shitanjing'
# 248.719
#
#
# 'Zhangjiakou'
# 251.094
#
#
# 'Marystown'
# 272.469
#
#
# 'Teguise'
# 289.15
#
#
# 'Preobrazheniye'
# 256.119

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

dictlist=[]
# Build query URL

for i in range(len(cities)):
    
    query_url = url + "appid=" + api_key + "&q=" + cities[i]
    
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    #pprint(f"The weather API responded with: {weather_json}.")
    
    if weather_json['cod'] == '404':
        continue
    else:    
        dictlist.append(weather_json)

# %%
weatherdf = pd.DataFrame(dictlist)
weatherdf

weatherdf.to_csv('./Weather.csv')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
weatherdf.head()
# Out:
#        base       clouds  cod                            coord          dt  \
# 0  stations  {'all': 90}  200   {'lon': -161.76, 'lat': 60.79}  1547582160
# 1  stations  {'all': 24}  200  {'lon': -134.97, 'lat': -23.12}  1547584419
# 2  stations  {'all': 80}  200     {'lon': 60.13, 'lat': 66.04}  1547584419
# 3  stations   {'all': 0}  200     {'lon': 34.53, 'lat': 10.07}  1547584419
# 4  stations  {'all': 76}  200     {'lon': 30.47, 'lat': 67.56}  1547584420
#
#         id                                               main     name rain  \
# 0  5880568  {'temp': 275.37, 'pressure': 1003, 'humidity':...   Bethel  NaN
# 1  4030556  {'temp': 300.119, 'pressure': 1029.78, 'humidi...  Rikitea  NaN
# 2  1505579  {'temp': 264.069, 'pressure': 1001.24, 'humidi...     Inta  NaN
# 3   343292  {'temp': 288.344, 'pressure': 895.14, 'humidit...    Asosa  NaN
# 4   543508  {'temp': 262.469, 'pressure': 978.47, 'humidit...   Kovdor  NaN
#
#   snow                                                sys  visibility  \
# 0  NaN  {'type': 1, 'id': 7640, 'message': 0.0047, 'co...     16093.0
# 1  NaN  {'message': 0.0034, 'country': 'PF', 'sunrise'...         NaN
# 2  NaN  {'message': 0.0042, 'country': 'RU', 'sunrise'...         NaN
# 3  NaN  {'message': 0.0032, 'country': 'ET', 'sunrise'...         NaN
# 4  NaN  {'message': 0.0034, 'country': 'RU', 'sunrise'...         NaN
#
#                                              weather  \
# 0  [{'id': 804, 'main': 'Clouds', 'description': ...
# 1  [{'id': 801, 'main': 'Clouds', 'description': ...
# 2  [{'id': 803, 'main': 'Clouds', 'description': ...
# 3  [{'id': 800, 'main': 'Clear', 'description': '...
# 4  [{'id': 803, 'main': 'Clouds', 'description': ...
#
#                               wind
# 0        {'speed': 3.6, 'deg': 90}
# 1  {'speed': 6.13, 'deg': 55.5005}
# 2    {'speed': 1.98, 'deg': 220.5}
# 3    {'speed': 1.43, 'deg': 349.5}
# 4  {'speed': 1.23, 'deg': 7.00046}

# %%
import matplotlib.pyplot as plt 

#note: I imported this down here because it takes so long to run the previous function. 

fig = plt.figure()
fig.set_size_inches(18.5, 10.5, forward=True)
ax = fig.add_subplot(111, aspect='equal')

ax.autoscale()

plt.ylabel('Temperature (K)')
plt.xlabel('Latitude')

for i in range(len(weatherdf)):
    plt.scatter(int(weatherdf['coord'][i]['lat']), int(weatherdf['main'][i]['temp']), linestyle='-')
    

      
    #print(weatherdf['coord'][i]['lat'], type(int(weatherdf['main'][i]['temp'])))
    #plt.plot(int(weatherdf['coord'][i]['lat']), int(weatherdf['main'][i]['temp']))

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig = plt.figure()
fig.set_size_inches(18.5, 10.5, forward=True)
ax = fig.add_subplot(111, aspect='equal')

ax.autoscale()

plt.ylabel('Humidity')
plt.xlabel('Latitude')

#Note: the following is to identify this outlier, and remove it if it is potentially incorrect.

for i in range(len(weatherdf)):
    plt.scatter(int(weatherdf['coord'][i]['lat']), int(weatherdf['main'][i]['humidity']), linestyle='-')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
